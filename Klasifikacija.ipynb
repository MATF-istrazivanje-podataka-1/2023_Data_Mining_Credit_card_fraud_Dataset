# %%
import csv
import numpy as np
import pandas as pd
import seaborn as sn

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\raden\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\raden\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\raden\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\raden\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\raden\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\raden\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\raden\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.21.5)

# %%
df = pd.read_csv('card_transdata.csv')

# %%
kolone = df.drop(['fraud'], axis = 1).columns
kolone
# Out:
# Index(['distance_from_home', 'distance_from_last_transaction',
#        'ratio_to_median_purchase_price', 'repeat_retailer', 'used_chip',
#        'used_pin_number', 'online_order'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000000, 8)

# %%
df.isna().any()
# Out:
# distance_from_home                False
# distance_from_last_transaction    False
# ratio_to_median_purchase_price    False
# repeat_retailer                   False
# used_chip                         False
# used_pin_number                   False
# online_order                      False
# fraud                             False
# dtype: bool

# %%
X = df.drop(['fraud'], axis = 1)
X.shape
# Out:
# (1000000, 7)

# %%
y = df['fraud']
y.shape
# Out:
# (1000000,)

# %%
from sklearn.preprocessing import Normalizer, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
y.unique()
# Out:
# array([0., 1.])

# %%
X.describe()
# Out:
#        distance_from_home  distance_from_last_transaction  \
# count      1000000.000000                  1000000.000000
# mean            26.628792                        5.036519
# std             65.390784                       25.843093
# min              0.004874                        0.000118
# 25%              3.878008                        0.296671
# 50%              9.967760                        0.998650
# 75%             25.743985                        3.355748
# max          10632.723672                    11851.104565
#
#        ratio_to_median_purchase_price  repeat_retailer       used_chip  \
# count                  1000000.000000   1000000.000000  1000000.000000
# mean                         1.824182         0.881536        0.350399
# std                          2.799589         0.323157        0.477095
# min                          0.004399         0.000000        0.000000
# 25%                          0.475673         1.000000        0.000000
# 50%                          0.997717         1.000000        0.000000
# 75%                          2.096370         1.000000        1.000000
# max                        267.802942         1.000000        1.000000
#
#        used_pin_number    online_order
# count   1000000.000000  1000000.000000
# mean          0.100608        0.650552
# std           0.300809        0.476796
# min           0.000000        0.000000
# 25%           0.000000        0.000000
# 50%           0.000000        1.000000
# 75%           0.000000        1.000000
# max           1.000000        1.000000

# %%
fig = plt.figure(figsize=(14, 10))

plt.boxplot(X[:1000])
plt.title('Boxplot')
#plt.bar(kolone, kolone.values)
plt.show()

# %% [markdown]
# ### Matrica korelacija

# %%
corr = df.corr().abs()
mask = np.triu(np.ones_like(corr, dtype=bool))
sn.heatmap(corr, annot=True, fmt=".2f", linewidths=.5, mask=mask, robust=True)
# Out:
# <AxesSubplot:>

# %%
tforan=y.value_counts()

plt.style.use("fivethirtyeight")
plt.pie(tforan,labels=['safe','fraud'],autopct="%1.5f%%")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, stratify = y, random_state=42)

# %%
normalizer = Normalizer()
scaler = StandardScaler()

# %%
X_train_normalized = normalizer.fit_transform(X_train)
X_test_normalized = normalizer.transform(X_test)

# %%
X_train_standardized = scaler.fit_transform(X_train)
X_test_standardized = scaler.transform(X_test)

# %%
pd.DataFrame(X_train_normalized).describe()
# Out:
#                    0              1              2              3  \
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean        0.807649       0.235789       0.176265       0.082600
# std         0.267766       0.300108       0.225828       0.083739
# min         0.000164       0.000002       0.000022       0.000000
# 25%         0.715973       0.019739       0.025567       0.019029
# 50%         0.949080       0.086508       0.078767       0.055333
# 75%         0.993584       0.347849       0.229773       0.121256
# max         1.000000       1.000000       0.999995       0.463995
#
#                    4              5              6
# count  900000.000000  900000.000000  900000.000000
# mean        0.042459       0.012110       0.079922
# std         0.094138       0.053152       0.120072
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.031258
# 75%         0.038935       0.000000       0.109654
# max         0.976186       0.965337       0.994736

# %%
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Vizelizacija podataka

# %%
pca1 = PCA(n_components = 2)

# %%
X_train_pca1 = pca1.fit_transform(X_train_normalized)
X_test_pca1 = pca1.transform(X_test_normalized)

# %%
class_names=y
scatter = plt.scatter(X_train_pca1[:4000,0], X_train_pca1[:4000,1], c=y_train[:4000])
plt.show()

# %%
pca2 = PCA(n_components = 3)

# %%
X_train_pca2 = pca2.fit_transform(X_train_normalized)
X_test_pca2 = pca2.transform(X_test_normalized)

# %%
class_names=y

scatter = plt.figure(figsize=(9,8)).add_subplot(111, projection='3d')
scatter.scatter(X_train_pca2[:4000, 0], X_train_pca2[:4000, 1], X_train_pca2[:4000, 2], c=y_train[:4000])

plt.show()

# %% [markdown]
# ### DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, get_scorer_names

# %%
param_tree = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [2, 4, 6, 8, 10, None],
    'min_samples_split': [10, 15, 20]
}

# %%
grid_search = GridSearchCV(DecisionTreeClassifier(random_state = 42), param_grid = param_tree, verbose = 2)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   1.6s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   1.7s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   1.8s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   1.6s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=10; total time=   1.8s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=15; total time=   1.8s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=15; total time=   1.5s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=15; total time=   1.9s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=15; total time=   1.9s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=15; total time=   1.8s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   1.8s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   1.6s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   1.8s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   1.6s
# [CV] END ..criterion=gini, max_depth=2, min_samples_split=20; total time=   1.8s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   3.3s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   3.3s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   2.5s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=10; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=15; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=15; total time=   3.1s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=15; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=15; total time=   2.8s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=15; total time=   3.5s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   3.6s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   3.7s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   3.0s
# [CV] END ..criterion=gini, max_depth=4, min_samples_split=20; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=10; total time=   4.5s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=10; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=10; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=10; total time=   2.6s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=10; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=15; total time=   4.2s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=15; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=15; total time=   3.2s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=15; total time=   2.7s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=15; total time=   3.6s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=20; total time=   4.0s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=20; total time=   3.5s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=20; total time=   3.3s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=20; total time=   2.5s
# [CV] END ..criterion=gini, max_depth=6, min_samples_split=20; total time=   3.8s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=10; total time=   4.2s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=10; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=10; total time=   3.5s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=10; total time=   2.9s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=10; total time=   3.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=15; total time=   4.2s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=15; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=15; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=15; total time=   2.9s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=15; total time=   3.3s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   4.2s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   3.3s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   3.4s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   2.7s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   3.4s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   3.7s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   3.5s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   3.7s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   2.7s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   3.9s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=15; total time=   4.6s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=15; total time=   4.0s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=15; total time=   3.7s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=15; total time=   2.8s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=15; total time=   3.4s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   4.2s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   3.2s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   3.2s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   2.7s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=20; total time=   3.1s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10; total time=   4.1s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10; total time=   3.5s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10; total time=   3.5s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10; total time=   2.5s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10; total time=   3.6s
# [CV] END criterion=gini, max_depth=None, min_samples_split=15; total time=   4.2s
# [CV] END criterion=gini, max_depth=None, min_samples_split=15; total time=   3.2s
# [CV] END criterion=gini, max_depth=None, min_samples_split=15; total time=   3.5s
# [CV] END criterion=gini, max_depth=None, min_samples_split=15; total time=   2.7s
# [CV] END criterion=gini, max_depth=None, min_samples_split=15; total time=   3.4s
# [CV] END criterion=gini, max_depth=None, min_samples_split=20; total time=   3.9s
# [CV] END criterion=gini, max_depth=None, min_samples_split=20; total time=   3.2s
# [CV] END criterion=gini, max_depth=None, min_samples_split=20; total time=   3.0s
# [CV] END criterion=gini, max_depth=None, min_samples_split=20; total time=   2.7s
# [CV] END criterion=gini, max_depth=None, min_samples_split=20; total time=   3.2s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10; total time=   2.0s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10; total time=   2.0s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=15; total time=   1.9s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=15; total time=   2.0s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=15; total time=   2.1s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=15; total time=   2.2s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=15; total time=   2.2s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=20; total time=   1.9s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=20; total time=   2.1s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=20; total time=   2.0s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=20; total time=   1.9s
# [CV] END criterion=entropy, max_depth=2, min_samples_split=20; total time=   2.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10; total time=   3.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10; total time=   2.9s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10; total time=   3.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10; total time=   3.3s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=10; total time=   3.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=15; total time=   3.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=15; total time=   3.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=15; total time=   2.9s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=15; total time=   3.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=15; total time=   3.2s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20; total time=   3.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20; total time=   3.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20; total time=   3.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20; total time=   3.1s
# [CV] END criterion=entropy, max_depth=4, min_samples_split=20; total time=   3.2s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=10; total time=   3.1s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=10; total time=   3.1s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=10; total time=   3.1s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=10; total time=   3.2s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=10; total time=   3.5s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=15; total time=   3.4s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=15; total time=   3.4s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=15; total time=   3.4s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=15; total time=   3.5s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=15; total time=   3.4s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=20; total time=   3.4s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=20; total time=   3.2s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=20; total time=   3.2s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=20; total time=   3.4s
# [CV] END criterion=entropy, max_depth=6, min_samples_split=20; total time=   3.3s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=10; total time=   3.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=10; total time=   3.2s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=10; total time=   3.4s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=10; total time=   3.4s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=10; total time=   3.4s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=15; total time=   3.5s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=15; total time=   2.9s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=15; total time=   3.2s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=15; total time=   3.2s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=15; total time=   3.1s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   3.0s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   3.2s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   3.3s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   3.2s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   3.0s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10; total time=   3.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10; total time=   3.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10; total time=   3.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10; total time=   3.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10; total time=   3.0s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=15; total time=   3.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=15; total time=   3.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=15; total time=   3.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=15; total time=   3.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=15; total time=   3.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=20; total time=   3.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=20; total time=   4.0s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=20; total time=   3.8s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=20; total time=   3.5s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=20; total time=   3.9s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   3.2s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   3.7s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   3.3s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   3.3s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   3.2s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=15; total time=   3.3s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=15; total time=   3.5s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=15; total time=   3.3s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=15; total time=   3.1s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=15; total time=   3.3s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   3.4s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   3.4s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   3.3s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   3.4s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=20; total time=   3.4s
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10, None],
#                          'min_samples_split': [10, 15, 20]},
#              verbose=2)

# %%
params = grid_search.best_params_
score = grid_search.best_score_

print(f'Najbolji parametri su {params} i accuracy je {score}')
# Out:
# Najbolji parametri su {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 10} i accuracy je 0.9999877777777778

# %%
model_tree = DecisionTreeClassifier(criterion=params['criterion'],
                               max_depth = params['max_depth'], min_samples_split=params['min_samples_split'])

# %%
model_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_split=10)

# %%
y_pred = model_tree.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[91260,     0],
#        [    1,  8739]], dtype=int64)

# %%
plt.figure(figsize=(20,15))
drvo = plot_tree(model_tree, filled = True)

# %%
print('test accuracy')
print(accuracy_score(y_test, y_pred))
print('-'*15)
print('test f1 score')
print(f1_score(y_test, y_pred))
# Out:
# test accuracy
# 0.99999
# ---------------
# test f1 score
# 0.9999427884890439

# %% [markdown]
# ### Balansiranje podataka i pravljenje neuronskih mreza za par algoritama balansiranja

# %%
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.neural_network import MLPClassifier

# %%
def imbalanced(X_train, y_train, sampler):
    X_resampled, y_resampled = sampler.fit_resample(X_train, y_train)
    print(f'X_resampled.shape = {X_resampled.shape}')
    print(f'y value counts = \n{y_resampled.value_counts()}')
    
    return X_resampled, y_resampled

# %%
sampler = SMOTE(random_state=42)
X_resampled_smote, y_resampled_smote = imbalanced(X_train_normalized, y_train, sampler)
# Out:
# X_resampled.shape = (1642674, 7)
# y value counts =
# 0.0    821337
# 1.0    821337
# Name: fraud, dtype: int64

# %%
model_MLP_smote = MLPClassifier(hidden_layer_sizes=(5,4,3), max_iter=500, random_state=42)

# %%
model_MLP_smote.fit(X_resampled_smote, y_resampled_smote)
# Out:
# MLPClassifier(hidden_layer_sizes=(5, 4, 3), max_iter=500, random_state=42)

# %%
y_pred_smote = model_MLP_smote.predict(X_test_normalized)

# %%
sampler = RandomOverSampler(random_state=42)
X_resampled_over, y_resampled_over = imbalanced(X_train_normalized, y_train, sampler)
# Out:
# X_resampled.shape = (1642674, 7)
# y value counts =
# 0.0    821337
# 1.0    821337
# Name: fraud, dtype: int64

# %%
model_MLP_over = MLPClassifier(hidden_layer_sizes=(5,4,3), max_iter=500, random_state=42)

# %%
model_MLP_over.fit(X_resampled_over, y_resampled_over)
# Out:
# MLPClassifier(hidden_layer_sizes=(5, 4, 3), max_iter=500, random_state=42)

# %%
y_pred_over = model_MLP_over.predict(X_test_normalized)

# %%
sampler = RandomUnderSampler(random_state=42)
X_resampled_under, y_resampled_under = imbalanced(X_train_normalized, y_train, sampler)
# Out:
# X_resampled.shape = (157326, 7)
# y value counts =
# 0.0    78663
# 1.0    78663
# Name: fraud, dtype: int64

# %%
model_MLP_under = MLPClassifier(hidden_layer_sizes=(5,4,3), max_iter=500, random_state=42)

# %%
model_MLP_under.fit(X_resampled_under, y_resampled_under)
# Out:
# MLPClassifier(hidden_layer_sizes=(5, 4, 3), max_iter=500, random_state=42)

# %%
y_pred_under = model_MLP_under.predict(X_test_normalized)

# %%
acc_smote = accuracy_score(y_test, y_pred_smote)
acc_over = accuracy_score(y_test, y_pred_over)
acc_under = accuracy_score(y_test, y_pred_under)
f_smote = f1_score(y_test, y_pred_smote)
f_over = f1_score(y_test, y_pred_over)
f_under = f1_score(y_test, y_pred_under)

fig = plt.figure(figsize = (13, 8))

scores = [acc_smote, f_smote, acc_over, f_over, acc_under, f_under]
samplers = ['acc_Smote', 'f_Smote', 'acc_Over_Sampler', 'f_Over_Sampler', 'acc_Under_Sampler', 'f_Under_Sampler']

bar = plt.bar(samplers, scores, color = 'maroon')

bar[1].set_color('lightblue')
bar[3].set_color('lightblue')
bar[5].set_color('lightblue')

plt.xlabel("Primenjeni algoritmi", fontsize = 12, fontweight='bold')
plt.ylabel("Preciznost za balansirane podatke", fontsize = 12, fontweight='bold')
plt.title("Uporedjivanje za MLP", fontsize=14, fontweight='bold')
plt.ylim([0,1.2])
for i, v in enumerate(scores):
    plt.text(i, v + 0.01, f'{v:.4f}', ha='center', color='black', fontweight='bold')

plt.show()

# %%
from sklearn.metrics import RocCurveDisplay, roc_auc_score

fig, ax = plt.subplots(figsize=(10, 8))

# ROC - Decision Tree model
roc_display1 = RocCurveDisplay.from_estimator(model_tree, X_test, y_test, ax=ax, name='Decision Tree')

# ROC - MLP model smote
roc_display2 = RocCurveDisplay.from_estimator(model_MLP_smote, X_test_normalized, y_test, ax=ax, name='MLP model smote')

# ROC - MLP model over sampler
roc_display3 = RocCurveDisplay.from_estimator(model_MLP_over, X_test_normalized, y_test, ax=ax, name='MLP model over sampler')

# ROC - MLP model under sampler
roc_display4 = RocCurveDisplay.from_estimator(model_MLP_under, X_test_normalized, y_test, ax=ax, name='MLP model under sampler')

plt.plot([0, 1], [0, 1], linestyle='--', color='red', label='Random Classifier')
plt.legend(loc='lower right', fontsize=12)

plt.xlabel('Lažno pozitivna stopa (FPR)', fontsize=14)
plt.ylabel('Tačno pozitivna stopa (TPR)', fontsize=14)

plt.show()

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
kfold = KFold(shuffle=True)

# %%
score_smote = cross_val_score(model_MLP_smote, X_test_normalized, y_test, cv=kfold, scoring='accuracy')

# %%
score_smote.mean()
# Out:
# 0.9831100000000002
